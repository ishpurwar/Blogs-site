# %% [markdown]
# <a href="https://colab.research.google.com/github/ishpurwar/Blogs-site/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
import glob

# %%
# !nvidia-smi
# Out:
# Tue Jun  6 03:58:38 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     8W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
HOME =os.getcwd()

# %%
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.1 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=911696577fa75f0824ea5788da965598f2e84bf38036a15b8c50f3bf3ad7be50
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="T871jW5w0kEM9bOrFpOZ")
project = rf.workspace("roboflow-100").project("road-signs-6ih4y")
dataset = project.version(2).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=6eed7ce80122a1d327e2aa8a2c9c587f9ec6576595c8f964ccab9f398e1919cb
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data='/content/datasets/road_signs/data.yaml' epochs=100 imgsz=640
# Out:
# /content
# ...

# %%
# !ls {HOME}/runs/detect/train2/
# Out:
# args.yaml					    train_batch2.jpg
# confusion_matrix.png				    train_batch7740.jpg
# events.out.tfevents.1686024226.f43d06fbe7ad.2809.0  train_batch7741.jpg
# F1_curve.png					    train_batch7742.jpg
# P_curve.png					    val_batch0_labels.jpg
# PR_curve.png					    val_batch0_pred.jpg
# predictions.json				    val_batch1_labels.jpg
# R_curve.png					    val_batch1_pred.jpg
# results.csv					    val_batch2_labels.jpg
# results.png					    val_batch2_pred.jpg
# train_batch0.jpg				    weights
# train_batch1.jpg

# %%
from IPython.display import Image

# %%
Image(filename=f"{HOME}/runs/detect/train2/confusion_matrix.png")

# %%
Image(filename= f"{HOME}/runs/detect/train2/val_batch2_pred.jpg",height=500)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/results.png',width=600)
# Out:
# /content

# %%
# !yolo task=detect mode=val model='/content/runs/detect/train2/weights/best.pt' data='/content/datasets/road_signs/data.yaml'
# Out:
# 2023-06-06 05:53:51.603113: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-06 05:53:52.745309: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 11133711 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/datasets/road_signs/valid/labels.cache... 488 images, 0 backgrounds, 0 corrupt: 100% 488/488 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:10<00:00,  2.84it/s]
#                    all        488        529      0.941      0.893      0.954      0.796
# ...

# %%
# !gdown "https://www.kapwing.com/videos/647c37744928c50011406dd7"
# Out:
# Downloading...
# From: https://www.kapwing.com/videos/647c37744928c50011406dd7
# To: /content/647c37744928c50011406dd7
# 10.9kB [00:00, 27.2MB/s]

# %%
# !gdown "https://www.kapwing.com/videos/647c3802c0a31a002403fe30"
# Out:
# Downloading...
# From: https://www.kapwing.com/videos/647c3802c0a31a002403fe30
# To: /content/647c3802c0a31a002403fe30
# 10.9kB [00:00, 619kB/s]

# %% [markdown]
# **testing** 1

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source='647c37744928c50011406dd7'
# Out:
# /content
# 2023-06-04 07:13:58.271611: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-04 07:13:59.653380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Error executing job with overrides: ['task=detect', 'mode=predict', 'model=/content/runs/detect/train2/weights/best.pt', 'conf=0.25', 'source=647c37744928c50011406dd7']
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cli.py", line 52, in cli
#     func(cfg)
#   File "/usr/local/lib/python3.10/dist-packages/hydra/main.py", line 83, in decorated_main
# ...

# %% [markdown]
# Display output demo video

# %%
! rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os
# Input video path
save_path = f' {HOME}/runs/detect/predict12/testtf1.mp4'
# Compressed video path compressed_path = "/content/result_compressed.mp4"
os.system(f" ffmpeg -i (save_path} -vcodec libx264 (compressed_path}")
# Show video
mp4 = open(compressed_path, 'rb').read()
data url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
 <source src="%s" type="video/mp4">
  </video> 
  """% data_url)

# %% [markdown]
# testing 2

# %%
# %cd {HOME} 
# !yolo task-detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf-0.25 source="647c37744928c50011406dd7"

# %%
# !rm "/content/result compressed.mp4"

# %% [markdown]
# Demo video 2

# %%
from IPython.display import HTML
from base64 import b64encode import os
# Input video path
save_path = f' {HOME}/runs/detect/predict16/roadsigns.mp4' 
# Compressed video path
compressed_path = "/content/result_compressed.mp4"
os.system(f" ffmpeg -i {save_path} -vcodec libx264 (compressed_path}")
# Show video
mp4 = open(compressed_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode() 
HTML ("""
<video width=400 controls>
<source src="%s" type="video/mp4">
</video>
""" % data_url)
